# %% [markdown]
# # Homework 4

# %% [markdown]
# ### Team:
# - Ariana Villegas
# - John-Ryan Romo

# %% [markdown]
# # Imports

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
from src.algorithm import ValueIteration
from src.tester import Tester
from src.env import GridWorld, Gambler

# %% [markdown]
# # Question 1

# %%
WORLD_SIZE = 5 #square
ACTION_PROB = 0.25 #pi(action, state)

A_POS = [0,1] #[1,1], [0, 1] # max reward pos
A_PRIME_POS = [4, 1]
B_POS = [0,3]  #[3,4],  [0, 3] # max reward pos
B_PRIME_POS = [2, 3]

# %%
env = GridWorld(WORLD_SIZE, A_POS, A_PRIME_POS, B_POS, B_PRIME_POS, ACTION_PROB)
tester = Tester(env)

# %%
tester.test(ValueIteration, gamma=0.9)

# %% [markdown]
# # Question 2

# %%
GOAL = 100

# %%
PROB_H = 0.4
env = Gambler(GOAL, PROB_H)
tester = Tester(env)
tester.test(ValueIteration)

# %%
PROB_H = 0.6
env = Gambler(GOAL, PROB_H)
tester = Tester(env)
tester.test(ValueIteration)
