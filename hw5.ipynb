# %% [markdown]
# # Homework 5

# %% [markdown]
# ### Team:
# - Ariana Villegas
# - John-Ryan Romo

# %% [markdown]
# # Imports

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
from src.algorithm import ValueIteration, FVMonteCarlo, ESoftPolicy
from src.tester import Tester
from src.env import GridWorld, Gambler

# %% [markdown]
# # Question 1

# %%
GOAL = 100
PROB_H = 0.4
GAMMA = 1

# %%
env = Gambler(GOAL, PROB_H)
reward = np.zeros(GOAL+1)
reward[GOAL] = 1
env.set_reward(reward)

# %%
algo = ValueIteration(env, GAMMA)
tester = Tester(env)
tester.test(algo)

# %%
reward[0] = -1
env.set_reward(reward)

# %%
algo = ValueIteration(env, GAMMA)
tester = Tester(env)
tester.test(algo)

# %% [markdown]
# The policy is the same when we use $0$ and $-1$ reward. The range of values is $[0,1]$ if we use a zero reward when the player runs out of money. The range of values is $[-1,1]$ if we use $-1$ reward when the player runs out of money. If the action set includes $0$ and we use $-1$ reward, we get the same policy.

# %% [markdown]
# # Question 2

# %%
GOAL = 50
PROB_H = 0.4

# %%
env = Gambler(GOAL, PROB_H)
reward = np.zeros(GOAL+1)
reward[GOAL] = 1
env.set_reward(reward)

# %%
policy = ESoftPolicy()
algo = FVMonteCarlo(env, GAMMA, policy)
tester = Tester(env)
tester.test(algo)

# %%
glob_reward = 0
for i in range(100):
    state, action, reward = algo.get_episode()
    glob_reward += np.sum(reward)

# %%
glob_reward
# Out:
# 44.0

# %%
policy = ESoftPolicy(0.01)
algo = FVMonteCarlo(env, GAMMA, policy)
tester = Tester(env)
tester.test(algo)

# %%
glob_reward1 = 0
for i in range(100):
    state, action, reward1 = algo.get_episode()
    glob_reward1 += np.sum(reward1)

# %%
glob_reward1
# Out:
# 35.0
